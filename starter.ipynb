# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffomanga88/Analyzing-Moringa-Data-Science/blob/main/starter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("I am running my first python code")
print("Congragulations!!!")
# Out:
# I am running my first python code
# Congragulations!!!

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

##Generating random values from 3 dimensions
x , y,scale = np.random.randn(3,100)
fig , ax = plt.subplots()

# %%
##Mapping into a scatterplot 
x , y,scale = np.random.randn(3,100)
fig , ax = plt.subplots()
ax.scatter(x=x , y=y ,c=scale ,s=np.abs(scale)*500)
ax.set(title="Random Data Generated")
plt.show()

# %%
# Out:
#   File "<ipython-input-7-07d61a30bb5f>", line 1
#     pip instal learntools
#              ^
# SyntaxError: invalid syntax
